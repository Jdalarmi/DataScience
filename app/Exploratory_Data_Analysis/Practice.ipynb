# %%
import pandas as pd

# %%
df = pd.read_excel('../My_Datas/Data/Groceries.xlsx')

# %%
df.sort_values('Price_Dollars', ascending=False)
# Out:
#    Product_ID               Category                   Item  Price_Dollars  \
# 23    P100033   Frozen: Frozen Fruit     Frozen Blueberries          10.99
# 11    P100021          Produce: Meat      Chicken (Organic)          10.49
# 10    P100020          Produce: Meat                   Beef           8.99
# 12    P100022          Produce: Meat                 Turkey           7.99
# 24    P100034   Frozen: Frozen Fruit       Frozen Pineapple           7.96
# 21    P100031  Frozen: Frozen Snacks        Chicken Nuggets           6.99
# 5     P100015         Produce: Fruit             Watermelon           5.99
# 19    P100029         Pantry: Snacks      Cookies (Oatmeal)           5.39
# 22    P100032  Frozen: Frozen Snacks            Spinach Dip           4.96
# 15    P100025         Produce: Dairy             Milk (Soy)           4.49
# 2     P100012         Produce: Fruit                 Grapes           4.00
# ...

# %%
df.head()
# Out:
#   Product_ID        Category                  Item  Price_Dollars  Inventory  \
# 0    P100010  Produce: Fruit                 Apple           1.50        349
# 1    P100011  Produce: Fruit                Banana           0.40        500
# 2    P100012  Produce: Fruit                Grapes           4.00        200
# 3    P100013  Produce: Fruit            Grapefruit           0.99         50
# 4    P100014  Produce: Fruit  Organic Strawberries           3.99        148
#
#          Last_Updated Next_Scheduled_Shipment
# 0 2023-06-12 15:35:00              2023-06-15
# 1 2023-06-12 18:30:00              2023-06-15
# 2 2023-06-12 17:22:00              2023-06-15
# 3 2023-06-12 16:29:00              2023-06-15
# 4 2023-06-12 18:10:00              2023-06-15

# %%
df.groupby("Category")["Inventory"].sum()
# Out:
# Category
# Frozen: Frozen Fruit      340
# Frozen: Frozen Snacks     161
# Pantry: Snacks            737
# Produce: Dairy           1098
# Produce: Fruit           1346
# Produce: Meat             617
# Produce: Vegetable        558
# Name: Inventory, dtype: int64

# %%
df.groupby("Category")["Inventory"].count()
# Out:
# Category
# Frozen: Frozen Fruit     2
# Frozen: Frozen Snacks    2
# Pantry: Snacks           4
# Produce: Dairy           4
# Produce: Fruit           6
# Produce: Meat            3
# Produce: Vegetable       4
# Name: Inventory, dtype: int64

# %%
df[["Category", "Item", "Price_Dollars"]].sort_values("Price_Dollars", ascending=False)
# Out:
#                  Category                   Item  Price_Dollars
# 23   Frozen: Frozen Fruit     Frozen Blueberries          10.99
# 11          Produce: Meat      Chicken (Organic)          10.49
# 10          Produce: Meat                   Beef           8.99
# 12          Produce: Meat                 Turkey           7.99
# 24   Frozen: Frozen Fruit       Frozen Pineapple           7.96
# 21  Frozen: Frozen Snacks        Chicken Nuggets           6.99
# 5          Produce: Fruit             Watermelon           5.99
# 19         Pantry: Snacks      Cookies (Oatmeal)           5.39
# 22  Frozen: Frozen Snacks            Spinach Dip           4.96
# 15         Produce: Dairy             Milk (Soy)           4.49
# 2          Produce: Fruit                 Grapes           4.00
# 4          Produce: Fruit   Organic Strawberries           3.99
# 13         Produce: Dairy                 Butter           3.50
# 14         Produce: Dairy                   Eggs           3.29
# ...

# %%
df.groupby(['Category'])['Price_Dollars'].mean().sort_values().plot.barh();

# %%
happiness = pd.read_csv('../My_Datas/Data/happiness_survey_data.csv')
happiness.head()
# Out:
#   country_name  year  happiness_score  social_support  \
# 0  Afghanistan  2008         3.723590        0.450662
# 1  Afghanistan  2009         4.401778        0.552308
# 2  Afghanistan  2010         4.758381        0.539075
# 3  Afghanistan  2011         3.831719        0.521104
# 4  Afghanistan  2012         3.782938        0.520637
#
#    freedom_to_make_life_choices  healthy_life_expectancy_at_birth
# 0                      0.718114                         50.500000
# 1                      0.678896                         50.799999
# 2                      0.600127                         51.099998
# 3                      0.495901                         51.400002
# 4                      0.530935                         51.700001

# %%
happiness[happiness.country_name == 'Mexico'].iloc[:, 1:3].plot.line(x="year", y="happiness_score")
# Out:
# <Axes: xlabel='year'>

# %%
happiness[happiness.country_name.isin(['Canada', 'Mexico', 'United States'])].iloc[:, :3].pivot(index='year', columns='country_name', values="happiness_score").plot.line()
# Out:
# <Axes: xlabel='year'>
